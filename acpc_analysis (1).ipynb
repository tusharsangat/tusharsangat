# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

import scipy.stats as stats

# %%
# %matplotlib inline
# from sklearn.metrics import accuracy_score
# from sklearn.model_selection import cross_val_score

# from sklearn.linear_model import LogisticRegression
# from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv("/content/meritbased1.csv",names=["college", "dept", "rank", "minmerit"])

# %%
df.head(5)
# Out:
#                                              college  \
# 0  Dhirubhai Ambani Institute of Info. & Comm. Te...
# 1  Dhirubhai Ambani Institute of Info. & Comm. Te...
# 2  Dhirubhai Ambani Institute of Info. & Comm. Te...
# 3  Faculty Of Technology And Engineering(GIA), Dh...
# 4  Institute Of Technology, Nirma University Of S...
#
#                                            dept   rank   minmerit
# 0  HONS. IN ICT WITH MINOR IN COMPUTATIONAL SCI   58.0  99.646077
# 1                     MATHEMATICS AND COMPUTING  123.0  99.333210
# 2        INFORMATION & COMMUNICATION TECHNOLOGY  158.0  99.243162
# 3                          COMPUTER ENGINEERING  265.0  98.805053
# 4                COMPUTER SCIENCE & ENGINEERING  325.0  98.615422

# %%
df.values
# Out:
# array([['Dhirubhai Ambani Institute of Info. & Comm. Tech., Gandhinagar',
#         'HONS. IN ICT WITH MINOR IN COMPUTATIONAL SCI', 58.0,
#         99.64607728],
#        ['Dhirubhai Ambani Institute of Info. & Comm. Tech., Gandhinagar',
#         'MATHEMATICS AND COMPUTING', 123.0, 99.33321025],
#        ['Dhirubhai Ambani Institute of Info. & Comm. Tech., Gandhinagar',
#         'INFORMATION & COMMUNICATION TECHNOLOGY', 158.0, 99.2431616],
#        ...,
#        ['SHREE DHANVANTARY COLLEGE OF ENGINEERING & TECHNOLOGY,\nKIM',
#         'COMPUTER SCIENCE & ENGINEERING (INTERNET OF', nan, nan],
#        ['SHREE DHANVANTARY COLLEGE OF ENGINEERING & TECHNOLOGY,\nKIM',
#         'COMPUTER SCIENCE & ENGINEERING (ARTIFICIAL IN', nan, nan],
#        ['SHREE DHANVANTARY COLLEGE OF ENGINEERING & TECHNOLOGY,\nKIM',
#         'CHEMICAL ENGINEERING (GREEN TECHNOLOGY AND', nan, nan]],
#       dtype=object)

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=798, step=1),
#  Index(['college', 'dept', 'rank', 'minmerit'], dtype='object')]

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 3192

# %%
# df.memory_usage

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 798 entries, 0 to 797
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   college   798 non-null    object
#  1   dept      798 non-null    object
#  2   rank      347 non-null    float64
#  3   minmerit  347 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 25.1+ KB

# %%
df.isnull().sum()
# Out:
# college       0
# dept          0
# rank        451
# minmerit    451
# dtype: int64

# %%
df.describe()
# Out:
#                rank    minmerit
# count    347.000000  347.000000
# mean   21197.360231   43.916667
# std    12217.740822   33.610132
# min       58.000000    0.195797
# 25%    10193.000000    9.647352
# 50%    22955.000000   43.218736
# 75%    33737.500000   74.376833
# max    34584.000000   99.646077

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 798 entries, 0 to 797
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   college   798 non-null    object
#  1   dept      798 non-null    object
#  2   rank      347 non-null    float64
#  3   minmerit  347 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 25.1+ KB

# %%
df.corr()
# Out:
#               rank  minmerit
# rank      1.000000 -0.996004
# minmerit -0.996004  1.000000

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# college     0
# dept        0
# rank        0
# minmerit    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# df.iloc[0].college

# %%
# df.values.tolist()

# %%
df.head(100)
# Out:
#                                               college  \
# 0   Dhirubhai Ambani Institute of Info. & Comm. Te...
# 1   Dhirubhai Ambani Institute of Info. & Comm. Te...
# 2   Dhirubhai Ambani Institute of Info. & Comm. Te...
# 3   Faculty Of Technology And Engineering(GIA), Dh...
# 4   Institute Of Technology, Nirma University Of S...
# ..                                                ...
# 95              Government Engineering College, Dahod
# 96             Ahmedabad Institute Of Tech, Ahmedabad
# 97        L.J. Institute Of Engg And Tech., Ahmedabad
# 98  R.N.G. Patel Institute of Technology-RNGPIT , ...
# 99  Indus Institute Of Tech. & Engg., Racharda, Ah...
#
#                                             dept     rank   minmerit
# 0   HONS. IN ICT WITH MINOR IN COMPUTATIONAL SCI     58.0  99.646077
# 1                      MATHEMATICS AND COMPUTING    123.0  99.333210
# 2         INFORMATION & COMMUNICATION TECHNOLOGY    158.0  99.243162
# ...

# %%
# done

# %%
# df['college'].apply(lambda x:[i.replace(","," ") for i in x])

# %%
Loc = df.iloc[0].college.split(sep=None)
Loc[-1]
# Out:
# 'Gandhinagar'

# %%
df['Location'] = df['college'].apply(lambda x:x.split(sep=None)[-1])

# %%
df.sample(5)
# Out:
#                                                college  \
# 304  Shri Sadvidhya Mandal Institute Of Tech., Bharuch
# 137  SCHOOL OF SCIENCE & ENGINEERING., Navrachana U...
# 52              Government Engineering College, Rajkot
# 332  ADITYA SILVER OAK INSTITUTE OF TECHNOLOGY (WIT...
# 67         Sarvajanik College Of Engg. & Tech. , Surat
#
#                                          dept     rank   minmerit   Location
# 304                      CHEMICAL ENGINEERING  34375.0   4.301045    Bharuch
# 137            COMPUTER SCIENCE & ENGINEERING  15448.0  61.843309   Vadodara
# 52                       COMPUTER ENGINEERING   5163.0  86.251112     Rajkot
# 332                    INFORMATION TECHNOLOGY  34520.0   2.229920  AHMEDABAD
# 67   ARTIFICIAL INTELLIGENCE AND DATA SCIENCE   7595.0  80.420514      Surat

# %%
# df['Govt'] = df['college'].apply(lambda x:1 if 'Government' in x  elif 'L.D.College Of Engineering, Ahmedabad' in x else 0 )
# # df['Govt'] = df['college'].apply(lambda x:1 if 'L.D.College Of Engineering, Ahmedabad' in x  else 0 )

# %%
def parse_values(x):
    if'Government' in x:
        return 1
    elif 'L.D.College Of Engineering, Ahmedabad' in x:
        return 1
    else:
        return 0

df['Govt'] = df['college'].apply(parse_values)

# %%
df.sample(5)
# Out:
#                                                college  \
# 307        Sarvajanik College Of Engg. & Tech. , Surat
# 58      New L.J. Institute of Engineering & Technology
# 241  School of Engineering - Indrashil University, ...
# 279  Asha M. Tarsadia Institute of Computer Science...
# 152  P.P. Savani School of Engineering, P.P. Savani...
#
#                                           dept     rank   minmerit  \
# 307                     ELECTRICAL ENGINEERING  34388.0   4.105819
# 58              COMPUTER SCIENCE & ENGINEERING   6068.0  84.107053
# 241         CHEMICAL & BIOCHEMICAL ENGINEERING  33431.0  11.327945
# 279  COMPUTER ENGINEERING (SOFTWARE ENGINEERIN  34157.0   6.412127
# 152             COMPUTER SCIENCE & ENGINEERING  18859.0  53.515795
#
#        Location  Govt
# 307       Surat     0
# 58   Technology     0
# 241        Kadi     0
# 279     Bardoli     0
# 152     Kosamba     0

# %%
df['dept'] = df['dept'].str.replace(" ","")
# df['college'] = df['college'].str.replace(" ","")

# %%
df['dept'] = df['dept'].apply(lambda x:x.lower())
df['Location'] = df['Location'].apply(lambda x:x.lower())
# df['college'] = df['college'].apply(lambda x:x.lower())

# %%
df['dept'] = df['dept'].str.replace("computerscience&engineering","computerengineering")

# %%
df.sample(5)
# Out:
#                                                college  \
# 97         L.J. Institute Of Engg And Tech., Ahmedabad
# 1    Dhirubhai Ambani Institute of Info. & Comm. Te...
# 216  Vishwakarma Government Engineering College,\nC...
# 219  Chandubhai S Patel Institute Of Technology, Ch...
# 196             Government Engineering College, Modasa
#
#                                      dept     rank   minmerit  \
# 97   artificialintelligenceanddatascience  11324.0  71.725242
# 1                 mathematicsandcomputing    123.0  99.333210
# 216                      powerelectronics  32209.0  16.951321
# 219                 electricalengineering  32576.0  15.550741
# 196  electronics&communicationengineering  27223.0  32.562291
#
#                    Location  Govt
# 97                ahmedabad     0
# 1               gandhinagar     0
# 216  chandkheda,gandhinagar     1
# 219                  changa     0
# 196                  modasa     1

# %%
df['college'].value_counts()
# Out:
# L.D.College Of Engineering, Ahmedabad                              14
# L.J. Institute Of Engg And Tech., Ahmedabad                        11
# Faculty Of Technology & Engineering(MSU), Vadodara                 10
# Sarvajanik College Of Engg. & Tech. , Surat                         9
# Parul Institute of Technology, Waghodia, Vadodara                   8
#                                                                    ..
# Narnarayan Shastri Institute of Technology, Jetalpur, Ahmedabad     1
# New L.J. Institute of Engineering & Technology                      1
# Bhagwan Mahavir College Of Engg. And Tech., Surat                   1
# Pacific School Of Engineering, Surat                                1
# Grow More Faculty of Engineering, Berna, Himmatnagar                1
# Name: college, Length: 112, dtype: int64

# %%
df['dept'].value_counts()
# Out:
# computerengineering                           98
# informationtechnology                         54
# civilengineering                              27
# electricalengineering                         25
# mechanicalengineering                         24
# chemicalengineering                           21
# electronics&communicationengineering          18
# information&communicationtechnology            9
# instrumentation&controlengineering             7
# environmentalengineering                       4
# artificialintelligenceanddatascience           4
# computerengineering(artificialin               4
# biomedicalengineering                          4
# automobileengineering                          3
# computerscience&design                         3
# textiletechnology                              2
# computerengineering(datascienc                 2
# computerengineering(cybersecur                 2
# biotechnology                                  2
# ...

# %%
for col in df.columns:
    print(col, ':',len(df[col].unique()),'labels')
# Out:
# college : 112 labels
# dept : 52 labels
# rank : 347 labels
# minmerit : 344 labels
# Location : 45 labels
# Govt : 2 labels

# %%
df1 = df[df['dept'] == 'informationtechnology']
print(df1.shape)
df1.head(5)
# Out:
# (54, 6)
#                                               college                   dept  \
# 9               L.D.College Of Engineering, Ahmedabad  informationtechnology
# 10  Faculty Of Technology(Sfi), Dharmsinh Desai Un...  informationtechnology
# 13  Vishwakarma Government Engineering College,\nC...  informationtechnology
# 14   Birla Vishvakarma Maha Vidhylaya(Sfi), V.V.Nagar  informationtechnology
# 22  Government Engineering College Sector 28, Gand...  informationtechnology
#
#       rank   minmerit                Location  Govt
# 9    855.0  96.963150               ahmedabad     1
# 10  1108.0  96.254742                  nadiad     0
# 13  1371.0  95.560045  chandkheda,gandhinagar     1
# 14  1594.0  94.916527               v.v.nagar     0
# 22  2261.0  93.204631             gandhinagar     1

# %%
filter_criteria = (df['dept'] == 'informationtechnology') & (df['Location'] == 'ahmedabad') & (df['Govt'] == 1)
df1m = df[filter_criteria]
print(df1m.shape)
df1m.head()
# Out:
# (1, 6)
#                                  college                   dept   rank  \
# 9  L.D.College Of Engineering, Ahmedabad  informationtechnology  855.0
#
#    minmerit   Location  Govt
# 9  96.96315  ahmedabad     1

# %%
df1_op = df[~filter_criteria]
df1_op.head()
# Out:
#                                              college  \
# 0  Dhirubhai Ambani Institute of Info. & Comm. Te...
# 1  Dhirubhai Ambani Institute of Info. & Comm. Te...
# 2  Dhirubhai Ambani Institute of Info. & Comm. Te...
# 3  Faculty Of Technology And Engineering(GIA), Dh...
# 4  Institute Of Technology, Nirma University Of S...
#
#                                     dept   rank   minmerit     Location  Govt
# 0  hons.inictwithminorincomputationalsci   58.0  99.646077  gandhinagar     0
# 1                mathematicsandcomputing  123.0  99.333210  gandhinagar     0
# 2    information&communicationtechnology  158.0  99.243162  gandhinagar     0
# 3                    computerengineering  265.0  98.805053       nadiad     0
# 4                    computerengineering  325.0  98.615422    ahmedabad     0

# %%
#ohe

# %%
pd.get_dummies(df,drop_first=True).shape
#OHE predicting columns
# Out:
# (347, 209)

# %%
#FE

# %%
# df.dept.value_counts().sort_values(ascending = False).head(20)

# %%
# df.dept.value_counts().to_dict()

# %%
# df.college.value_counts().to_dict()

# %%
# df.college.value_counts().sort_values(ascending = False).head(20)

# %%
# df_frequency_map = df.dept.value_counts().to_dict()
# df_college_counts = df.college.value_counts().to_dict()
# df_Location_counts = df.Location.value_counts().to_dict()

# %%
# df.dept = df.dept.map(df_frequency_map)
# df.college = df.college.map(df_college_counts)
# df.Location = df.Location.map(df_Location_counts)

# %%
# df.head(100)

# %%
# inv_map = {v: k for k, v in df.dept.items()}

# %%
# inv_map = {v: k for k, v in df.dept.items()}

# %%
# dict((v, k) for k, v in df.college.items())

# %%
# inv_map = {}
# for k, v in df.college.items():
#     inv_map[v] = inv_map.get(v, []) + [k]

# %%
# def inverse_mapping(f):
#     return f.__class__(map(reversed, f.items()))

# %%
# # df.dept = inverse_mapping(df_college_counts)
# df.dept = df.dept.inverse_mapping(df_college_counts)

# %%
# from collections import Counter, defaultdict

# def invert_dict(d):
#     d_inv = defaultdict(list)
#     for k, v in d.items():
#         d_inv[v].append(k)
#     return d_inv

# # text = 'aaa bbb ccc ddd aaa bbb ccc aaa' 
# # c = Counter(text.split()) # Counter({'aaa': 3, 'bbb': 2, 'ccc': 2, 'ddd': 1})
# dict(invert_dict(df_frequency_map)) # {1: ['ddd'], 2: ['bbb', 'ccc'], 3: ['aaa']}

# %%
df.head()
# Out:
#                                              college  \
# 0  Dhirubhai Ambani Institute of Info. & Comm. Te...
# 1  Dhirubhai Ambani Institute of Info. & Comm. Te...
# 2  Dhirubhai Ambani Institute of Info. & Comm. Te...
# 3  Faculty Of Technology And Engineering(GIA), Dh...
# 4  Institute Of Technology, Nirma University Of S...
#
#                                     dept   rank   minmerit     Location  Govt
# 0  hons.inictwithminorincomputationalsci   58.0  99.646077  gandhinagar     0
# 1                mathematicsandcomputing  123.0  99.333210  gandhinagar     0
# 2    information&communicationtechnology  158.0  99.243162  gandhinagar     0
# 3                    computerengineering  265.0  98.805053       nadiad     0
# 4                    computerengineering  325.0  98.615422    ahmedabad     0

# %%
import seaborn as sns

# %%
sns.countplot(df['minmerit'])
# df['rank'].value_counts().plot(kind='bar')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(df['rank'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.pairplot(df,hue='minmerit')

# %%
df['Govt'].value_counts().plot(kind = 'bar')

# %%
sns.barplot(x = df['Govt'],y = df['minmerit'])

# %%
sns.displot(df['rank'])

# %%
sns.displot(df['minmerit'])

# %%
df['college'].value_counts().plot(kind='bar')

# %%
df['dept'].value_counts().plot(kind='bar')

# %%
sns.barplot(y=df['minmerit'],x=df['college'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(y=df['minmerit'],x=df['dept'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.scatterplot(x = df['college'],y = df['minmerit'])
plt.xticks(rotation='vertical')
plt.show()

# %%
import plotly.express as px
fig  = px.scatter_3d(df,x= df['college'], y = df['dept'], z = df['minmerit'],color = df['Govt'].astype('str'))
fig.update_traces(marker=dict(size = 12,line= dict(width = 2,color = 'DarkSlateGrey')),selector = dict(mode ='markers'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# from sklearn.preprocessing import StandardScaler
# std_scaler = StandardScaler()
# df = std_scaler.fit_transform(df.to_numpy())
# df = pd.DataFrame(df_scaled, columns=[
#   'college','dept','rank','minmerit','Location','Govt'])
# df_scaled.head()

# %%
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows how to understand word labels.
le = preprocessing.LabelEncoder()

df['college']= le.fit_transform(df['college'])
df['dept']= le.fit_transform(df['dept'])
df['Location']= le.fit_transform(df['Location'])

# %%
df.head()
# Out:
#    college  dept   rank   minmerit  Location  Govt
# 0       22    33   58.0  99.646077        15     0
# 1       22    38  123.0  99.333210        15     0
# 2       22    34  158.0  99.243162        15     0
# 3       25    12  265.0  98.805053        26     0
# 4       50    12  325.0  98.615422         3     0

# %%
import plotly.express as px
fig  = px.scatter_3d(df,x= df['college'], y = df['dept'], z = df['minmerit'],color = df['Govt'].astype('str'))
fig.update_traces(marker=dict(size = 12,line= dict(width = 2,color = 'DarkSlateGrey')),selector = dict(mode ='markers'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from sklearn.preprocessing import StandardScaler
std_scaler = StandardScaler()
df_scaled = std_scaler.fit_transform(df.to_numpy())
df_scaled = pd.DataFrame(df_scaled, columns=[
  'college','dept','rank','minmerit','Location','Govt'])
print("Scaled Dataset Using StandardScaler")
df = df_scaled
df.head()
# Out:
# Scaled Dataset Using StandardScaler
#     college      dept      rank  minmerit  Location      Govt
# 0 -1.037280  0.906802 -1.732717  1.660508 -0.363549 -0.542933
# 1 -1.037280  1.314499 -1.727389  1.651186 -0.363549 -0.542933
# 2 -1.037280  0.988342 -1.724520  1.648503 -0.363549 -0.542933
# 3 -0.937372 -0.805524 -1.715750  1.635449  0.432132 -0.542933
# 4 -0.104803 -0.805524 -1.710832  1.629798 -1.231566 -0.542933

# %%
import plotly.express as px
fig  = px.scatter_3d(df,x= df['college'], y = df['dept'], z = df['minmerit'],color = df['Govt'].astype('str'))
fig.update_traces(marker=dict(size = 12,line= dict(width = 2,color = 'DarkSlateGrey')),selector = dict(mode ='markers'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# y = df.drop(columns = ['rank'])
# X = df['rank']
# y = df['college']

# %%
X = df.iloc[:, [2,3]]
y= df.iloc[:, [0,1,4,5]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state = 2)

# %%
X_train
# Out:
#          rank  minmerit
# 210  0.825536 -0.694517
# 257  1.023239 -1.010907
# 157 -0.142979  0.237496
# 314  1.084222 -1.197700
# 340  1.094632 -1.262154
# ..        ...       ...
# 299  1.075943 -1.163242
# 22  -1.552145  1.468579
# 72  -1.090674  1.066915
# 15  -1.606571  1.519344
# 168  0.022101  0.089644
#
# [277 rows x 2 columns]

# %%
X_test
# Out:
#          rank  minmerit
# 67  -1.114936  1.087665
# 170  0.054150  0.062142
# 20  -1.564358  1.479626
# 99  -0.795349  0.813486
# 286  1.067501 -1.135189
# ..        ...       ...
# 315  1.085861 -1.205789
# 35  -1.441244  1.367547
# 317  1.086681 -1.211167
# 70  -1.103871  1.078237
# 10  -1.646652  1.559460
#
# [70 rows x 2 columns]

# %%
y_train
# Out:
#       college      dept  Location      Govt
# 210 -0.071500  0.336027 -1.231566 -0.542933
# 257  0.527950 -0.153209  0.142793 -0.542933
# 157  1.527033 -0.805524  1.227813 -0.542933
# 314  0.394739 -0.805524  0.793805 -0.542933
# 340  1.427124  0.336027 -1.448570 -0.542933
# ..        ...       ...       ...       ...
# 299 -0.737556  0.988342  0.215128 -0.542933
# 22  -0.670950  1.069881 -0.363549  1.841848
# 72  -1.370308  1.396038  1.372483 -0.542933
# 15  -0.970675 -1.131682  1.444817 -0.542933
# 168  1.260611 -1.131682 -1.231566 -0.542933
#
# [277 rows x 4 columns]

# %%
y_test
# Out:
#       college      dept  Location      Govt
# 67   1.227308 -1.539378  0.938475 -0.542933
# 170  0.194922  2.048353 -1.231566 -0.542933
# 20  -1.237097 -0.805524 -0.580553 -0.542933
# 99  -0.138106  1.069881 -1.231566 -0.542933
# 286  1.660244  1.069881 -1.231566 -0.542933
# ..        ...       ...       ...       ...
# 315  1.127400  1.069881  1.661821 -0.542933
# 35  -0.970675  1.396038  1.444817 -0.542933
# 317 -0.071500 -0.887064 -1.231566 -0.542933
# 70   1.926666  0.417566 -0.363549  1.841848
# 10  -0.904069  1.069881  0.432132 -0.542933
#
# [70 rows x 4 columns]

# %%
X_train
# Out:
#          rank  minmerit
# 210  0.825536 -0.694517
# 257  1.023239 -1.010907
# 157 -0.142979  0.237496
# 314  1.084222 -1.197700
# 340  1.094632 -1.262154
# ..        ...       ...
# 299  1.075943 -1.163242
# 22  -1.552145  1.468579
# 72  -1.090674  1.066915
# 15  -1.606571  1.519344
# 168  0.022101  0.089644
#
# [277 rows x 2 columns]

# %%
df.head()
# Out:
#     college      dept      rank  minmerit  Location      Govt
# 0 -1.037280  0.906802 -1.732717  1.660508 -0.363549 -0.542933
# 1 -1.037280  1.314499 -1.727389  1.651186 -0.363549 -0.542933
# 2 -1.037280  0.988342 -1.724520  1.648503 -0.363549 -0.542933
# 3 -0.937372 -0.805524 -1.715750  1.635449  0.432132 -0.542933
# 4 -0.104803 -0.805524 -1.710832  1.629798 -1.231566 -0.542933

# %%
import plotly.express as px
fig  = px.scatter_3d(df,x= df['college'], y = df['dept'], z = df['minmerit'],color = df['Govt'].astype('str'))
fig.update_traces(marker=dict(size = 12,line= dict(width = 2,color = 'DarkSlateGrey')),selector = dict(mode ='markers'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# X_test

# %%
# y_test

# %%
lr.predict(X_test.iloc[1].values.reshape(1,-1))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning:
#
# X does not have valid feature names, but LinearRegression was fitted with feature names
# array([[ 0.00097222, -0.02693173,  0.12013423, -0.05692164]])

# %%
y_pred1 = lr.predict(X_test)
y_pred1
# Out:
# array([[-0.22833329, -0.06915561, -0.12569246,  0.06838856],
#        [ 0.00097222, -0.02693173,  0.12013423, -0.05692164],
#        [-0.31699557, -0.08495025, -0.2224127 ,  0.11778954],
#        [-0.16425904, -0.05879916, -0.05247056,  0.0307983 ],
#        [ 0.13016104,  0.06902075,  0.03188059,  0.00134648],
#        [-0.22742797, -0.06902746, -0.12460078,  0.06782499],
#        [ 0.13524105,  0.06168507,  0.06331571, -0.01619976],
#        [ 0.14065241,  0.04946405,  0.11064828, -0.04276005],
#        [-0.14396062, -0.0561217 , -0.02737819,  0.01781233],
#        [ 0.05238158, -0.0146588 ,  0.16642906, -0.08000394],
#        [ 0.14321648,  0.03208448,  0.16949   , -0.07604   ],
#        [ 0.02248073, -0.02163455,  0.13899245, -0.06628863],
#        [ 0.04698923, -0.01602847,  0.16183198, -0.07772991],
#        [-0.33822605, -0.09296938, -0.23225921,  0.12205244],
#        [-0.11098153, -0.04920397,  0.00532181,  0.00129901],
# ...

# %%
from sklearn import metrics
print('Mae',metrics.mean_absolute_error(y_test,y_pred1))
print('Mse',metrics.mean_squared_error(y_test,y_pred1))
print('rmse',np.sqrt(metrics.mean_absolute_error(y_test,y_pred1)))
# Out:
# Mae 0.8855426742847752
# Mse 1.021606060420801
# rmse 0.9410327700376726

# %%
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.multioutput import MultiOutputClassifier

# knn = KNeighborsClassifier(n_neighbors=3)
# classifier = MultiOutputClassifier(knn, n_jobs=-1)
# classifier.fit(X_train,y_train)
# # classifier = KNeighborsClassifier(n_neighbors=3)
# # classifier.fit(X_train,y_train)

# %%
# y_pred  = classifier.predict(X_test)
# # y_pred

# %%
# # import the regressor
# from sklearn.tree import DecisionTreeRegressor

# # create a regressor object
# regressor = DecisionTreeRegressor(random_state = 0)

# # fit the regressor with X and Y data
# regressor.fit(X_train,y_train)

# %%
# # predicting a new value

# # test the output by changing values, like 3750
# y_pred2 = regressor.predict([X_test])

# # print the predicted price
# # print("Predicted price: % d\n"% y_pred)

# %%
# from sklearn.metrics import classification_report, confusion_matrix
# print(classification_report(y_test,y_pred1))
# print(confusion_matrix(y_test,y_pred1))

# %%
  # from sklearn.compose import ColumnTransformer
# from sklearn.pipeline import Pipeline
# from sklearn.preprocessing import OneHotEncoder
# from sklearn.metrics import r2_score,mean_absolute_error

# %%
# from sklearn.linear_model import LinearRegression,Ridge,Lasso
# from sklearn.neighbors import KNeighborsRegressor
# from sklearn.tree import DecisionTreeRegressor
# from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
# from sklearn.svm import SVR
# from xgboost import XGBRegressor

# %%
# X_train= X_train.array.reshape(1, -1)
# X_test = X_test.array.reshape(-1, 1)

# %%
# step1 = LinearRegression()

# pipe = Pipeline([
#     ('step1',step1)
  
# ])

# pipe.fit(X_train,y_train)

# y_pred = pipe.predict(X_test)

# print('R2 score',r2_score(y_test,y_pred))
# print('MAE',mean_absolute_error(y_test,y_pred))
