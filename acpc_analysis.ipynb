# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
# %matplotlib inline

# from sklearn.metrics import accuracy_score
# from sklearn.model_selection import cross_val_score

# from sklearn.linear_model import LogisticRegression
# from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv("/content/meritbased1.csv",names=["college", "dept", "rank", "minmerit"])

# %%
df.head(5)
# Out:
#                                              college  \
# 0  Dhirubhai Ambani Institute of Info. & Comm. Te...
# 1  Dhirubhai Ambani Institute of Info. & Comm. Te...
# 2  Dhirubhai Ambani Institute of Info. & Comm. Te...
# 3  Faculty Of Technology And Engineering(GIA), Dh...
# 4  Institute Of Technology, Nirma University Of S...
#
#                                            dept   rank   minmerit
# 0  HONS. IN ICT WITH MINOR IN COMPUTATIONAL SCI   58.0  99.646077
# 1                     MATHEMATICS AND COMPUTING  123.0  99.333210
# 2        INFORMATION & COMMUNICATION TECHNOLOGY  158.0  99.243162
# 3                          COMPUTER ENGINEERING  265.0  98.805053
# 4                COMPUTER SCIENCE & ENGINEERING  325.0  98.615422

# %%
# df.values

# %%
# df.axes

# %%
# df.ndim

# %%
# df.size

# %%
# df.memory_usage

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 798 entries, 0 to 797
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   college   798 non-null    object
#  1   dept      798 non-null    object
#  2   rank      347 non-null    float64
#  3   minmerit  347 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 25.1+ KB

# %%
df.isnull().sum()
# Out:
# college       0
# dept          0
# rank        451
# minmerit    451
# dtype: int64

# %%
df.describe()
# Out:
#                rank    minmerit
# count    347.000000  347.000000
# mean   21197.360231   43.916667
# std    12217.740822   33.610132
# min       58.000000    0.195797
# 25%    10193.000000    9.647352
# 50%    22955.000000   43.218736
# 75%    33737.500000   74.376833
# max    34584.000000   99.646077

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 798 entries, 0 to 797
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   college   798 non-null    object
#  1   dept      798 non-null    object
#  2   rank      347 non-null    float64
#  3   minmerit  347 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 25.1+ KB

# %%
# df.corr()

# %%
# sns.countplot(df['minmerit'])
# #df['rank'].value_counts().plot(kind='bar')

# %%
# sns.countplot(df['rank'])

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# college     0
# dept        0
# rank        0
# minmerit    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# df.iloc[0].college

# %%
# df.values.tolist()

# %%
df.head()
# Out:
#                                              college  \
# 0  Dhirubhai Ambani Institute of Info. & Comm. Te...
# 1  Dhirubhai Ambani Institute of Info. & Comm. Te...
# 2  Dhirubhai Ambani Institute of Info. & Comm. Te...
# 3  Faculty Of Technology And Engineering(GIA), Dh...
# 4  Institute Of Technology, Nirma University Of S...
#
#                                            dept   rank   minmerit
# 0  HONS. IN ICT WITH MINOR IN COMPUTATIONAL SCI   58.0  99.646077
# 1                     MATHEMATICS AND COMPUTING  123.0  99.333210
# 2        INFORMATION & COMMUNICATION TECHNOLOGY  158.0  99.243162
# 3                          COMPUTER ENGINEERING  265.0  98.805053
# 4                COMPUTER SCIENCE & ENGINEERING  325.0  98.615422

# %%
# df['college'].apply(lambda x:[i.replace(","," ") for i in x])

# %%
Loc = df.iloc[0].college.split(sep=None)
Loc[-1]
# Out:
# 'Gandhinagar'

# %%
df['Location'] = df['college'].apply(lambda x:x.split(sep=None)[-1])

# %%
# Loc = df.iloc[0].college.split(sep=None)
# List = []
# if Loc[0] == Govenrment:
#   List = List.append

# %%
df.sample(5)
# Out:
#                                                college  \
# 273  Chhotubhai Gopalbhai Patel Institute Of Tech.,...
# 221        Smt. S.R. Patel Engg. College, Dabhi, Unjha
# 188           Government Engineering College, Palanpur
# 284  Shri Sitaram N Patel Inst. Of Tech. & Res. (Vi...
# 146  Parul Institute of Engineering & Technology, W...
#
#                        dept     rank   minmerit  Location
# 273    COMPUTER ENGINEERING  34022.0   7.556698   Bardoli
# 221    COMPUTER ENGINEERING  32678.0  15.175546     Unjha
# 188       CIVIL ENGINEERING  26017.0  35.593118  Palanpur
# 284    CHEMICAL ENGINEERING  34209.0   5.913969    Umrakh
# 146  INFORMATION TECHNOLOGY  17860.0  55.937674  Vadodara

# %%
# if'Government' in x:
#     return 1
# elif 'L.D.College Of Engineering, Ahmedabad' in x:
#     return 1
# else:
#     return 0

# %%
def parse_values(x):
    if'Government' in x:
        return 1
    elif 'L.D.College Of Engineering, Ahmedabad' in x:
        return 1
    else:
        return 0

# df['college'].apply(parse_values)
df['Govt'] = df['college'].apply(parse_values)

# %%
# df['Govt'] = df['college'].apply(lambda x:1 if 'Government' in x  elif 'L.D.College Of Engineering, Ahmedabad' in x else 0 )
# # df['Govt'] = df['college'].apply(lambda x:1 if 'L.D.College Of Engineering, Ahmedabad' in x  else 0 )

# %%
df.sample(5)
# Out:
#                                                college  \
# 79               Government Engineering College, Patan
# 135  Madhuben & Bhanubhai Patel Institute of Techno...
# 342              Government Engineering College, Dahod
# 261  Sardar Vallabhbhai Patel Institute Of Tech.,Vasad
# 71                                  L.E.College ,Morbi
#
#                                dept     rank   minmerit     Location  Govt
# 79   COMPUTER SCIENCE & ENGINEERING   9280.0  76.536293        Patan     1
# 135            COMPUTER ENGINEERING  15257.0  62.201812    V.V.Nagar     0
# 342               CIVIL ENGINEERING  34560.0   1.101676        Dahod     1
# 261          MECHANICAL ENGINEERING  33773.0   9.345926  Tech.,Vasad     0
# 71           INFORMATION TECHNOLOGY   7772.0  79.993771       ,Morbi     0

# %%
df['dept'] = df['dept'].str.replace(" ","")
# df['college'] = df['college'].str.replace(" ","")

# %%
df['dept'] = df['dept'].apply(lambda x:x.lower())
df['Location'] = df['Location'].apply(lambda x:x.lower())
# df['college'] = df['college'].apply(lambda x:x.lower())

# %%
df.sample(5)
# Out:
#                                                college  \
# 205  Unitedworld School of Computational Intelligen...
# 310          K.J. Institute Of Engg. And Tech., Savali
# 16    Pandit Deendayal Energy University , Gandhinagar
# 268          C.U.Shah College Of Engg.& Tech., Wadhvan
# 59         L.J. Institute Of Engg And Tech., Ahmedabad
#
#                                          dept     rank   minmerit  \
# 205  computerscience&engineering(artificialin  29704.0  25.597337
# 310                     informationtechnology  34407.0   3.933216
# 16                        computerengineering   1665.0  94.697064
# 268                       computerengineering  33931.0   8.292608
# 59                computerscience&engineering   6215.0  83.722044
#
#         Location  Govt
# 205  gandhinagar     0
# 310       savali     0
# 16   gandhinagar     0
# 268      wadhvan     0
# 59     ahmedabad     0

# %%
# input_dept
# input_Location

# %%
df1 = df[df['dept'] == 'informationtechnology']
print(df1.shape)
df1.head(5)
# Out:
# (54, 6)
#                                               college                   dept  \
# 9               L.D.College Of Engineering, Ahmedabad  informationtechnology
# 10  Faculty Of Technology(Sfi), Dharmsinh Desai Un...  informationtechnology
# 13  Vishwakarma Government Engineering College,\nC...  informationtechnology
# 14   Birla Vishvakarma Maha Vidhylaya(Sfi), V.V.Nagar  informationtechnology
# 22  Government Engineering College Sector 28, Gand...  informationtechnology
#
#       rank   minmerit                Location  Govt
# 9    855.0  96.963150               ahmedabad     1
# 10  1108.0  96.254742                  nadiad     0
# 13  1371.0  95.560045  chandkheda,gandhinagar     1
# 14  1594.0  94.916527               v.v.nagar     0
# 22  2261.0  93.204631             gandhinagar     1

# %%
filter_criteria = (df['dept'] == 'informationtechnology') & (df['Location'] == 'ahmedabad') & (df['Govt'] == 1)
df1m = df[filter_criteria]
print(df1m.shape)
df1m.head()
# Out:
# (1, 6)
#                                  college                   dept   rank  \
# 9  L.D.College Of Engineering, Ahmedabad  informationtechnology  855.0
#
#    minmerit   Location  Govt
# 9  96.96315  ahmedabad     1

# %%
df1_op = df[~filter_criteria]
df1_op.head()
# Out:
#                                              college  \
# 0  Dhirubhai Ambani Institute of Info. & Comm. Te...
# 1  Dhirubhai Ambani Institute of Info. & Comm. Te...
# 2  Dhirubhai Ambani Institute of Info. & Comm. Te...
# 3  Faculty Of Technology And Engineering(GIA), Dh...
# 4  Institute Of Technology, Nirma University Of S...
#
#                                     dept   rank   minmerit     Location  Govt
# 0  hons.inictwithminorincomputationalsci   58.0  99.646077  gandhinagar     0
# 1                mathematicsandcomputing  123.0  99.333210  gandhinagar     0
# 2    information&communicationtechnology  158.0  99.243162  gandhinagar     0
# 3                    computerengineering  265.0  98.805053       nadiad     0
# 4            computerscience&engineering  325.0  98.615422    ahmedabad     0

# %%
for col in df.columns:
    print(col, ':',len(df[col].unique()),'labels')
# Out:
# college : 112 labels
# dept : 53 labels
# rank : 347 labels
# minmerit : 344 labels
# Location : 45 labels
# Govt : 2 labels

# %%
pd.get_dummies(df,drop_first=True).shape
# Out:
# (347, 210)

# %%
df['dept'] = df['dept'].str.replace("computerscience&engineering","computerengineering")

# %%
# df.dept.value_counts().sort_values(ascending = False).head(20)

# %%
# df.dept.value_counts().to_dict()

# %%
# df.college.value_counts().to_dict()

# %%
# df.college.value_counts().sort_values(ascending = False).head(20)

# %%
df_frequency_map = df.dept.value_counts().to_dict()
df_college_counts = df.college.value_counts().to_dict()
df_Location_counts = df.Location.value_counts().to_dict()

# %%
df.dept = df.dept.map(df_frequency_map)
df.college = df.college.map(df_college_counts)
df.Location = df.Location.map(df_Location_counts)

# %%
df.head()
# Out:
#    college  dept   rank   minmerit  Location  Govt
# 0        3     1   58.0  99.646077        39     0
# 1        3     1  123.0  99.333210        39     0
# 2        3     9  158.0  99.243162        39     0
# 3        5    98  265.0  98.805053        11     0
# 4        7    98  325.0  98.615422        66     0

# %%
# inv_map = {v: k for k, v in df.dept.items()}

# %%
# inv_map = {v: k for k, v in df.dept.items()}

# %%
# dict((v, k) for k, v in df.college.items())

# %%
# inv_map = {}
# for k, v in df.college.items():
#     inv_map[v] = inv_map.get(v, []) + [k]

# %%
# def inverse_mapping(f):
#     return f.__class__(map(reversed, f.items()))

# %%
# # df.dept = inverse_mapping(df_college_counts)
# df.dept = df.dept.inverse_mapping(df_college_counts)

# %%
df.head()
# Out:
#    college  dept   rank   minmerit  Location  Govt
# 0        3     1   58.0  99.646077        39     0
# 1        3     1  123.0  99.333210        39     0
# 2        3     9  158.0  99.243162        39     0
# 3        5    98  265.0  98.805053        11     0
# 4        7    98  325.0  98.615422        66     0

# %%
# sns.pairplot(df,hue='minmerit')

# %%
# df['Govt'].value_counts().plot(kind = 'bar')

# %%
# sns.barplot(x = df['Govt'],y = df['minmerit'])

# %%
# sns.displot(df['rank'])

# %%
# sns.displot(df['minmerit'])

# %%
# df['college'].value_counts().plot(kind='bar')

# %%
# df['dept'].value_counts().plot(kind='bar')

# %%
# sns.barplot(y=df['minmerit'],x=df['college'])
# plt.xticks(rotation='vertical')
# plt.show()

# %%
# sns.barplot(y=df['minmerit'],x=df['dept'])
# plt.xticks(rotation='vertical')
# plt.show()

# %%
# sns.scatterplot(x = df['college'],y = df['minmerit'])
# plt.xticks(rotation='vertical')
# plt.show()

# %%
df['college'].value_counts()
# Out:
# 2     76
# 5     55
# 3     54
# 6     30
# 7     28
# 4     28
# 1     24
# 14    14
# 11    11
# 10    10
# 9      9
# 8      8
# Name: college, dtype: int64

# %%
df['dept'].value_counts()
# Out:
# 98    98
# 54    54
# 1     32
# 27    27
# 25    25
# 24    24
# 21    21
# 18    18
# 4     16
# 2     10
# 9      9
# 7      7
# 3      6
# Name: dept, dtype: int64

# %%
# from sklearn.preprocessing import StandardScaler
# std_scaler = StandardScaler()
# df = std_scaler.fit_transform(df.to_numpy())
# df = pd.DataFrame(df_scaled, columns=[
#   'college','dept','rank','minmerit','Location','Govt'])
# df_scaled.head()
from sklearn.preprocessing import StandardScaler
std_scaler = StandardScaler()
df_scaled = std_scaler.fit_transform(df.to_numpy())
df_scaled = pd.DataFrame(df_scaled, columns=[
  'college','dept','rank','minmerit','Location','Govt'])
print("Scaled Dataset Using StandardScaler")
df = df_scaled
df.head()
# Out:
# Scaled Dataset Using StandardScaler
#     college      dept      rank  minmerit  Location      Govt
# 0 -0.569716 -1.180083 -1.732717  1.660508  0.560696 -0.542933
# 1 -0.569716 -1.180083 -1.727389  1.651186  0.560696 -0.542933
# 2 -0.569716 -0.963594 -1.724520  1.648503  0.560696 -0.542933
# 3  0.065948  1.444846 -1.715750  1.635449 -0.668483 -0.542933
# 4  0.701612  1.444846 -1.710832  1.629798  1.745976 -0.542933

# %%
# y = df.drop(columns = ['rank'])
X = df.iloc[:, [2,3]]
# X = df['rank']
# y = df['college']
y= df.iloc[:, [0,1,4,5]]

# %%
# plt.scatter(X,y)
# plt.xlabel('X')
# plt.ylabel('y')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state = 2)

# %%
X_train
# Out:
#          rank  minmerit
# 210  0.825536 -0.694517
# 257  1.023239 -1.010907
# 157 -0.142979  0.237496
# 314  1.084222 -1.197700
# 340  1.094632 -1.262154
# ..        ...       ...
# 299  1.075943 -1.163242
# 22  -1.552145  1.468579
# 72  -1.090674  1.066915
# 15  -1.606571  1.519344
# 168  0.022101  0.089644
#
# [277 rows x 2 columns]

# %%
X_test
# Out:
#          rank  minmerit
# 67  -1.114936  1.087665
# 170  0.054150  0.062142
# 20  -1.564358  1.479626
# 99  -0.795349  0.813486
# 286  1.067501 -1.135189
# ..        ...       ...
# 315  1.085861 -1.205789
# 35  -1.441244  1.367547
# 317  1.086681 -1.211167
# 70  -1.103871  1.078237
# 10  -1.646652  1.559460
#
# [70 rows x 2 columns]

# %%
y_train
# Out:
#       college      dept  Location      Govt
# 210 -0.569716 -0.530616  1.745976 -0.542933
# 257  0.065948 -1.180083 -0.931879 -0.542933
# 157 -0.251884  1.444846 -0.975778 -0.542933
# 314 -0.569716  1.444846 -0.361189 -0.542933
# 340 -0.887548 -0.530616 -1.063577 -0.542933
# ..        ...       ...       ...       ...
# 299 -0.251884 -0.963594 -0.624584 -0.542933
# 22  -0.251884  0.254156  0.560696  1.841848
# 72   0.383780 -0.557677 -0.668483 -0.542933
# 15   1.655108 -0.638861  0.385099 -0.542933
# 168 -0.887548 -0.638861  1.745976 -0.542933
#
# [277 rows x 4 columns]

# %%
y_test
# Out:
#       college      dept  Location      Govt
# 67   1.337276 -1.098900 -0.097793 -0.542933
# 170  1.972939 -1.180083  1.745976 -0.542933
# 20   0.065948  1.444846 -0.800181 -0.542933
# 99  -0.569716  0.254156  1.745976 -0.542933
# 286 -0.887548  0.254156  1.745976 -0.542933
# ..        ...       ...       ...       ...
# 315 -0.887548  0.254156 -1.063577 -0.542933
# 35   1.655108 -0.557677  0.385099 -0.542933
# 317 -0.569716 -0.476494  1.745976 -0.542933
# 70   0.701612 -0.720044  0.560696  1.841848
# 10   0.383780  0.254156 -0.668483 -0.542933
#
# [70 rows x 4 columns]

# %%
X_train
# Out:
#          rank  minmerit
# 210  0.825536 -0.694517
# 257  1.023239 -1.010907
# 157 -0.142979  0.237496
# 314  1.084222 -1.197700
# 340  1.094632 -1.262154
# ..        ...       ...
# 299  1.075943 -1.163242
# 22  -1.552145  1.468579
# 72  -1.090674  1.066915
# 15  -1.606571  1.519344
# 168  0.022101  0.089644
#
# [277 rows x 2 columns]

# %%
df.head()
# Out:
#     college      dept      rank  minmerit  Location      Govt
# 0 -0.569716 -1.180083 -1.732717  1.660508  0.560696 -0.542933
# 1 -0.569716 -1.180083 -1.727389  1.651186  0.560696 -0.542933
# 2 -0.569716 -0.963594 -1.724520  1.648503  0.560696 -0.542933
# 3  0.065948  1.444846 -1.715750  1.635449 -0.668483 -0.542933
# 4  0.701612  1.444846 -1.710832  1.629798  1.745976 -0.542933

# %%
import plotly.express as px
fig  = px.scatter_3d(df,x= df['college'], y = df['dept'], z = df['minmerit'],color = df['Govt'].astype('str'))
fig.update_traces(marker=dict(size = 12,line= dict(width = 2,color = 'DarkSlateGrey')),selector = dict(mode ='markers'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1bb87465-e920-4bc0-a2e8-844ab29bc47d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1bb87465-e920-4bc0-a2e8-844ab29bc47d")) {                    Plotly.newPlot(                        "1bb87465-e920-4bc0-a2e8-844ab29bc47d",                        [{"hovertemplate":"color=-0.5429328866471298<br>college=%{x}<br>dept=%{y}<br>minmerit=%{z}<extra></extra>","legendgroup":"-0.5429328866471298","marker":{"color":"#636efa","symbol":"circle","line":{"color":"DarkSlateGrey","width":2},"size":12},"mode":"markers","name":"-0.5429328866471298","scene":"scene","showlegend":true,"x":[-0.5697160451881648,-0.5697160451881648,-0.5697160451881648,0.06594783802821204,0.7016117212445888,1.655107546069154,0.3837797796364004,0.3837797796364004,0.3837797796364004,-1.2053799284045417,-0.5697160451881648,1.655107546069154,0.7016117212445888,0.3837797796364004,0.7016117212445888,0.06594783802821204,0.7016117212445888,0.3837797796364004,0.06594783802821204,0.06594783802821204,
#       college      dept  Location      Govt
# 67   1.337276 -1.098900 -0.097793 -0.542933
# 170  1.972939 -1.180083  1.745976 -0.542933
# 20   0.065948  1.444846 -0.800181 -0.542933
# 99  -0.569716  0.254156  1.745976 -0.542933
# 286 -0.887548  0.254156  1.745976 -0.542933
# ..        ...       ...       ...       ...
# 315 -0.887548  0.254156 -1.063577 -0.542933
# 35   1.655108 -0.557677  0.385099 -0.542933
# 317 -0.569716 -0.476494  1.745976 -0.542933
# 70   0.701612 -0.720044  0.560696  1.841848
# 10   0.383780  0.254156 -0.668483 -0.542933
#
# [70 rows x 4 columns]

# %%
lr.predict(X_test.iloc[1].values.reshape(1,-1))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning:
#
# X does not have valid feature names, but LinearRegression was fitted with feature names
# array([[-0.04075992, -0.11993485,  0.00335658, -0.05692164]])

# %%
y_pred1 = lr.predict(X_test)
y_pred1
# Out:
# array([[ 3.62124664e-01,  1.65585984e-01,  2.97519592e-01,
#          6.83885626e-02],
#        [-4.07599217e-02, -1.19934849e-01,  3.35657912e-03,
#         -5.69216350e-02],
#        [ 5.17331509e-01,  2.77130477e-01,  4.09843628e-01,
#          1.17789535e-01],
#        [ 2.51096330e-01,  8.26934843e-02,  2.19163813e-01,
#          3.07982970e-02],
#        [-3.45241175e-01, -1.25156161e-01, -3.54607025e-01,
#          1.34648227e-03],
#        [ 3.60575438e-01,  1.64375584e-01,  2.96460899e-01,
#          6.78249888e-02],
#        [-3.45283995e-01, -1.49320171e-01, -3.39090809e-01,
#         -1.61997640e-02],
#        [-3.40596929e-01, -1.84564760e-01, -3.10823273e-01,
#         -4.27600455e-02],
#        [ 2.16571126e-01,  5.51321327e-02,  1.95948502e-01,
#          1.78123321e-02],
#        [-1.34099009e-01, -1.77894538e-01, -7.00697181e-02,
#         -8.00039360e-02],
#        [-3.25930332e-01, -2.26258938e-01, -2.66558069e-01,
#         -7.60399986e-02],
#        [-7.99853478e-02, -1.43833476e-01, -2.77960911e-02,
#         -6.62886276e-02],
#        [-1.24220183e-01, -1.71992760e-01, -6.21486009e-02,
#         -7.77299050e-02],
#        [ 5.59046642e-01,  2.94701971e-01,  4.48026918e-01,
#          1.22052445e-01],
#        [ 1.57720110e-01,  1.58905506e-02,  1.51390480e-01,
#          1.29901264e-03],
#        [-1.73797813e-01, -2.06218189e-01, -9.89334382e-02,
#         -9.24891892e-02],
#        [ 1.89459675e-01,  3.76728385e-02,  1.75023089e-01,
#          1.06543177e-02],
#        [-3.06397529e-01, -2.39073368e-01, -2.35123169e-01,
#         -8.93308910e-02],
#        [-1.33923381e-01, -1.77608183e-01, -7.00457776e-02,
#         -7.98316989e-02],
#        [-3.35407667e-01, -2.39043214e-02, -4.08166468e-01,
#          7.29008639e-02],
#        [ 5.06938948e-01,  2.70573794e-01,  4.01734767e-01,
#          1.15144434e-01],
#        [ 2.65222457e-01,  9.01911409e-02,  2.31097091e-01,
#          3.33660093e-02],
#        [-3.44827757e-01, -1.05367026e-01, -3.66865055e-01,
#          1.56388770e-02],
#        [-3.30190831e-01, -2.18885269e-01, -2.76364287e-01,
#         -6.98146804e-02],
#        [ 2.21820827e-01,  5.90986450e-02,  1.99622989e-01,
#          1.96239456e-02],
#        [ 4.81291160e-01,  2.53595620e-01,  3.82236332e-01,
#          1.08037616e-01],
#        [-3.44692214e-01, -1.59012051e-01, -3.32144804e-01,
#         -2.33614639e-02],
#        [-3.36076659e-01, -2.00902182e-01, -2.94934121e-01,
#         -5.55504128e-02],
#        [ 4.42369853e-02, -6.54051034e-02,  6.90928785e-02,
#         -3.46308047e-02],
#        [ 2.54131362e-01,  8.35742312e-02,  2.22198082e-01,
#          3.08195329e-02],
#        [-1.24516152e-01, -1.72531967e-01, -6.21524560e-02,
#         -7.80613089e-02],
#        [-2.37610283e-03, -9.24837306e-02,  3.12219163e-02,
#         -4.48022421e-02],
#        [-3.54092188e-02, -1.16219083e-01,  7.31246274e-03,
#         -5.53127740e-02],
#        [-3.43664453e-01, -8.68350320e-02, -3.77423317e-01,
#          2.88651209e-02],
#        [ 4.75497119e-01,  2.50270980e-01,  3.77502369e-01,
#          1.06803269e-01],
#        [-3.43271134e-01, -8.33754018e-02, -3.79185343e-01,
#          3.12983478e-02],
#        [ 3.58270894e-01,  1.62664470e-01,  2.94828441e-01,
#          6.70516049e-02],
#        [ 5.44582465e-01,  2.91223633e-01,  4.33103136e-01,
#          1.22473641e-01]])

# %%
# y_pred1

# %%
# plt.scatter(X_test, y_test, color = 'blue')
# plt.plot(X_train, lr.predict(X_train), color='red' )
# plt.title('acpc')
# plt.xlabel('x')
# plt.ylabel('y')
# plt.show()

# %%
from sklearn import metrics
print('Mae',metrics.mean_absolute_error(y_test,y_pred1))
print('Mse',metrics.mean_squared_error(y_test,y_pred1))
print('rmse',np.sqrt(metrics.mean_absolute_error(y_test,y_pred1)))
# Out:
# Mae 0.8544594075234082
# Mse 1.061447578287315
# rmse 0.9243697352917869

# %%
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.multioutput import MultiOutputClassifier

# knn = KNeighborsClassifier(n_neighbors=3)
# classifier = MultiOutputClassifier(knn, n_jobs=-1)
# classifier.fit(X_train,y_train)
# # classifier = KNeighborsClassifier(n_neighbors=3)
# # classifier.fit(X_train,y_train)

# %%
# y_pred  = classifier.predict(X_test)
# # y_pred

# %%
# # import the regressor
# from sklearn.tree import DecisionTreeRegressor

# # create a regressor object
# regressor = DecisionTreeRegressor(random_state = 0)

# # fit the regressor with X and Y data
# regressor.fit(X_train, y_train)

# %%
# # predicting a new value

# # test the output by changing values, like 3750
# y_pred2 = regressor.predict()

# # print the predicted price
# # print("Predicted price: % d\n"% y_pred)

# %%
# from sklearn.metrics import classification_report, confusion_matrix
# print(classification_report(y_test,y_pred))
# print(confusion_matrix(y_test,y_pred))

# %%
  # from sklearn.compose import ColumnTransformer
# from sklearn.pipeline import Pipeline
# from sklearn.preprocessing import OneHotEncoder
# from sklearn.metrics import r2_score,mean_absolute_error

# %%
# from sklearn.linear_model import LinearRegression,Ridge,Lasso
# from sklearn.neighbors import KNeighborsRegressor
# from sklearn.tree import DecisionTreeRegressor
# from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
# from sklearn.svm import SVR
# from xgboost import XGBRegressor

# %%
# X_train= X_train.array.reshape(1, -1)
# X_test = X_test.array.reshape(-1, 1)

# %%
# step1 = LinearRegression()

# pipe = Pipeline([
#     ('step1',step1)
  
# ])

# pipe.fit(X_train,y_train)

# y_pred = pipe.predict(X_test)

# print('R2 score',r2_score(y_test,y_pred))
# print('MAE',mean_absolute_error(y_test,y_pred))
